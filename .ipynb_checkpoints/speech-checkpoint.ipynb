# %%
#https://www.youtube.com/watch?v=K_WbsFrPUCk 
#Speech recognition source
#text to speech from Stringer example
#https://www.datacamp.com/community/tutorials/pandas-tutorial-dataframe-python#question2
#to be able to talk into microphone
import speech_recognition as sr
#to be able to convert text and have speaker say it 
from os import system as sys
#to extract data from sites
import requests 
#to extract import html components from sites
from bs4 import BeautifulSoup
import time
import pandas as pd
import numpy as np
import requests
from IPython.display import display, HTML


#print(data[0].iloc[0][1])
#make dictionary of locations and match their time stamps w values
def GetDestinyUsa():
    response = requests.get('https://www.syracuse.com/destiny-usa/index.ssf/2014/07/destiny_usa_hours_syracuse_mall_stores_restaurants_entertainment_directory.html')
    data = pd.read_html(website)
    characters = data_dict['results']
    return characters


#computer speak and sometimes print what is said
def say_this(text,print_):
    sys("say %s" % (text))
    if print_ != "n":
        print(text)
        
#Getting Stock information 
#Getting html from nasdaq for stocks
def get_Nasdaq_html(symbol):
    url = 'http://www.nasdaq.com/symbol/' + symbol
    response = requests.get(url)
    if response.ok:
        return response.text
    else:
        return "Error retrieving " + url
    
#Taking useless information out of stock html 
def extract_stock_data(html):
    soup = BeautifulSoup(html, "lxml")
    name = soup.select("div#qwidget_pageheader h1")[0].text
    price = soup.select("div#qwidget_lastsale")[0].text
    change = soup.select("div#qwidget_percent")[0].text
    stock= { 'Name' : name,
            "Price" : price,
            "Change" : change
    }
    return stock

def find_stock_info(symbol):
    html = get_Nasdaq_html(symbol)
    stock = extract_stock_data(html)
    print("Name: %s" % stock['Name'])
    print("Price: %s" % stock['Price'])
    print("Change: %s" % stock['Change'])

    


website = 'https://www.syracuse.com/destiny-usa/index.ssf/2014/07/destiny_usa_hours_syracuse_mall_stores_restaurants_entertainment_directory.html#shop-a'
data = pd.read_html(website)
print(type(data[0]))
pd.set_option('display.max_rows', 132)
               
              
r = sr.Recognizer()



with sr.Microphone() as source:
    say_this("Say something : ", "y")
    audio = r.listen(source)
    try:
        text = r.recognize_google(audio)
        print("You said: {}".format(text))
        #several if cases to do different actions when spoken to
        
        
        #Find information about Destiny USA
        if "destiny" in text or "Destiny" in text:
            say_this("Would you like to know about the stores, outlets, or dining options in Destiny USA?", "y")
            audio = r.listen(source)
            #try:
            text = r.recognize_google(audio)
            print("You said: {}".format(text))
                
                #Several if cases to perform different Destiny information tasks
            if "store" in text or "stores" in text or "Store" in text or "Stores" in text:
                say_this("Is there a specific store i should look for?",'y')
                audio = r.listen(source)
                try: 
                    text = r.recognize_google(audio)
                    print("You said: {}".format(text))
                
                    user_input = text.title()
                    try:
                        if[data[0]["Name"].str.contains(user_input)]:
                            this = data[0][data[0]["Name"].str.contains(user_input)]
                            display(this)
                            print("Store name")
                            display(this)
                            print(" Hours ")
                            display(this.iloc[0]["Hours"])
                            

                    except IndexError:
                        print("could not find your store")
                        print("Here's a comprehensive list of all the stores in the mall")
                        display(data[0])

                                
                except:
                    print("Could not hear you")

                    
            
            elif "Outlets" in text or "Outlet" in text or "outlets" in text or "outlet" in text:
                say_this("Here's a comprehensive list of all outlets in the mall", "y")
                display(data[1])
                    
            elif "dining options" in text or "food" in text:
                say_this("Here's a comprehensive list of all restaurants in the mall", "y")
                display(data[2])
                
            else:
                say_this("I could not find what you are looking for", "y")
                
            
            
            
        #Find a stock from the Nasdaq using stocksymbol
        elif "stock" in text:
            say_this("say What stock symbol should i look for? : ", "y")
            audio = r.listen(source)
            try:
                text = r.recognize_google(audio)
                print("You said: {}".format(text))
                stock_symbol = text
                find_stock_info(stock_symbol)
            except: 
                print("Could not find stock")
                
                
        #find current local time
        elif "time" in text:
            say_this("Would you like to know what time it is now? :", "y")
            audio = r.listen(source)
            try:
                text = r.recognize_google(audio)
                print("You said: {}".format(text))
                if text != "no":
                    print(time.asctime())
                else:
                    say_this("Sorry i must have misheard", "y")
            except:
                 print("Could not hear a yes or no")
    except:
        print("You did not say anything")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Say something :
# You said: destiny
# Would you like to know about the stores, outlets, or dining options in Destiny USA?
# You said: show me the stores
# Is there a specific store i should look for?
# You said: show me Justice
# Empty DataFrame
# Columns: [Name, Hours]
# Index: []
# Store name
# Empty DataFrame
# Columns: [Name, Hours]
# Index: []
#  Hours
# could not find your store
# Here's a comprehensive list of all the stores in the mall
#                                Name  \
# 0             Abercrombie and Fitch
# 1                             Aerie
# 2                       Aeropostale
# 3                  Against All Odds
# 4                              Aldo
# 5         American Eagle Outfitters
# 6                        Ann Taylor
# 7                             Apple
# 8          Around the World Imports
# 9                The Art of Shaving
# 10                  Banana Republic
# 11                    Bare Minerals
# 12              Bath and Body Works
# 13                BC Surf and Sport
# 14                         Best Buy
# 15                   Body by Pagoda
# 16                          Bon-Ton
# 17                           Branch
# 18                       Brookstone
# 19                           Buckle
# 20            Build-A-Bear Workshop
# 21                         Carhartt
# 22                         Cell Ace
# 23                    Champs Sports
# 24                  Charlotte Russe
# 25             The Children's Place
# 26              Christmas Treasures
# 27              Christopher & Banks
# 28                         Claire's
# 29                           Clarks
# 30                            Coach
# 31           Cooperstown Connection
# 32                Crabtree & Evelyn
# 33            Dick's Sporting Goods
# 34                     Disney Store
# 35                        Dressbarn
# 36                              DSW
# 37          Eastern Mountain Sports
# 38                          Express
# 39                  Famous Footwear
# 40                      Finish Line
# 41                       Five Below
# 42                          Flormar
# 43                      Foot Locker
# 44                   FootAction USA
# 45                       Forever 21
# 46                   Forever Bridal
# 47          Francesca's Collections
# 48                         GameStop
# 49                           Garage
# 50         Gertrude Hawk Chocolates
# 51                       Gift-ology
# 52                              GNC
# 53                         Gymboree
# 54                              H&M
# 55                         Hallmark
# 56                Hannoush Jewelers
# 57                        Hollister
# 58                        Hot Topic
# 59                   House of Hoops
# 60               Hubby's Happy Feet
# 61                         iComfort
# 62                           J.Crew
# 63                           J.Jill
# 64                         JCPenney
# 65    Jared The Galleria of Jewelry
# 66              Jay St. Video Games
# 67                         Journeys
# 68                    Journeys Kidz
# 69                          Justice
# 70                     Kay Jewelers
# 71                 Kids Foot Locker
# 72                 Lady Foot Locker
# 73                      Lane Bryant
# 74                             Lids
# 75                      The Limited
# 76                  Lindt Chocolate
# 77                 Littman Jewelers
# 78                             Loft
# 79                    Lord & Taylor
# 80                        Lululemon
# 81                           Macy's
# 82                         Michaels
# 83                        Microsoft
# 84             Motherhood Maternity
# 85         My Favorite Sports Store
# 86             New York and Company
# 87                New York Fashions
# 88                     99 Cent City
# 89                           Oakley
# 90                         Old Navy
# 91                 Olde Wicker Mill
# 92                           PacSun
# 93                      Pagoda Plus
# 94                          Pandora
# 95                           Papaya
# 96                          Papyrus
# 97               Payless ShoeSource
# 98                       Perfumania
# 99                             Pink
# 100    Play the Game Read the Story
# 101                    Pottery Barn
# 102               Salt of the Earth
# 103                         Sephora
# 104  Sleep Number by Select Comfort
# 105                  Soma Intimates
# 106                       Spencer's
# 107                Sports Authority
# 108                    Steve Madden
# 109                     StreetGames
# 110                     Stride Rite
# 111                    Sunglass Hut
# 112                       Swarovski
# 113                         Teavana
# 114        The Sock and Hosiery Hut
# 115               Things Remembered
# 116                         Toyland
# 117          University Sports Shop
# 118                          Vanity
# 119                        Via Roma
# 120               Victoria's Secret
# 121                           Villa
# 122                   Vitamin World
# 123                 Walking Company
# 124                        Wet Seal
# 125      White House | Black Market
# 126                 Williams-Sonoma
# 127           Yankee Candle Company
# 128                           Zales
# 129                          Zumiez
#
#                                                  Hours
# 0      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 1      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 2      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 3      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 4      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 5      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 6      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 7      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 8      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 9      Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 10     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 11     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 12     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 13     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 14        Mon.-Sat. 10 a.m.-9 p.m. Sun. 11 a.m.-7 p.m.
# 15     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 16   Mon.-Thu. 10 a.m.-9:45 p.m. Fri.-Sat. 10 a.m.-...
# 17     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 18     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 19     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 20     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 21     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 22     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 23     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 24     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 25     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 26     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 27     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 28     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 29     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 30     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 31     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 32     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 33      Mon.-Sat. 9 a.m.-9:30 p.m. Sun. 10 a.m.-7 p.m.
# 34     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 35     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 36     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 37     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 38     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 39     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 40     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 41     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 42     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 43     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 44     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 45     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 46     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 47     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 48     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 49     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 50     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 51     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 52     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 53     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 54     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 55     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 56     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 57     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 58     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 59     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 60     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 61     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 62     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 63     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 64     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 65     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 66     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 67     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 68     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 69     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 70     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 71     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 72     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 73     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 74     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 75     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 76     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 77     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 78     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 79   Mon.-Thu. 10 a.m.-9:45 p.m. Fri.-Sat. 10 a.m.-...
# 80                                         Coming soon
# 81   Mon.-Thu. 10 a.m.-9:30 p.m. Fri. 10 a.m.-10 p....
# 82     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 83     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 84     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 85     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 86     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 87     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 88     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 89     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 90     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 91     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 92     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 93     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 94     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 95     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 96     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 97     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 98     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 99     Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 100    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 101    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 102    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 103    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 104    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 105    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 106    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 107    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 108    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 109    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 110    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 111    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 112    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 113    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 114    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 115    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 116    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 117    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 118    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 119    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 120    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 121    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 122    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 123     Mon.-Sat. 9 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 124    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 125    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 126    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 127    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 128    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# 129    Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.

# %%
#user_input = int(input("Enter number: "))
#display(data[0].iloc[user_input]["Name"])
#display(data[0].iloc[user_input]["Hours"])
#data[0].iloc[0]['Hours']

x,y = data[0].count()
#print(x)

#for i in range(x):
 #   #display(data[0].iloc[i][0])
  #  if"Dick's" in data[0].iloc[i][0]:
   #     display(data[0].iloc[i]["Hours"]) 

    
user_input = input("Enter a name").title()
try:
    if[data[0]["Name"].str.contains(user_input)]:
        this = data[0][data[0]["Name"].str.contains(user_input)]
        display(this)
        print("Store name")
        display(this.iloc[0]["Name"])
        print(" Hours ")
        display(this.iloc[0]["Hours"])

except IndexError:
    print("could not find your store")
    print("Here's a comprehensive list of all the stores in the mall")
    display(data[0])
    
fitch = 0
aerie = 1
# Out:
# Enter a namejustice
#        Name                                            Hours
# 69  Justice  Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.
# Store name
# 'Justice'
#  Hours
# 'Mon.-Sat. 10 a.m.-9:30 p.m. Sun. 11 a.m.-6 p.m.'

# %%
import webbrowser
serch = input("What would you like to search? ")
webbrowser.open("https://www.google.com/search?q= %s" %(serch))
# Out:
# What would you like to search? Abercrombie
# True

# %%
https://developers.google.com/places/web-service/details
